# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Crea un Pipeline llamado model que primero trasforme el espacio con un polinomio de grado 30 (sin incluir p0) y, posteriormente, considera la transformación de los datos con una regresión logística sin regularización.
# (LogisticRegression(penalty='none'))

# %%
from sklearn.datasets import make_moons
X, y = make_moons(200,noise=0.2, random_state=2718)
plt.scatter(*X.T,c=y,cmap="Set2")

# %%
# Se separan los datos en train y test al 80/20
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=314)

# %%
# Se crea model con las caracteristicas del ejercicio y se netrena

model = Pipeline([("poly", PolynomialFeatures(30,include_bias=False)),
                  ("logreg", LogisticRegression(penalty='none'))
                 ])
model.fit(x_train, y_train)
# Out:
# /Users/danielpoblano/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Pipeline(memory=None,
#          steps=[('poly',
#                  PolynomialFeatures(degree=30, include_bias=False,
#                                     interaction_only=False, order='C')),
#                 ('logreg',
#                  LogisticRegression(C=1.0, class_weight=None, dual=False,
#                                     fit_intercept=True, intercept_scaling=1,
#                                     l1_ratio=None, max_iter=100,
# ...

# %% [markdown]
# Realizar un Bagging Classifier de model llamado bagging_logreg con n_estimators=100 y random_state=314

# %%
# Se crea bagging con las características 
# n_estimators es el número de muestras para encontrar n estimadores

from sklearn.ensemble import BaggingClassifier
bagging_logreg = BaggingClassifier(model, n_estimators=100, random_state=314)

# %% [markdown]
# Entrena model y bagging_logreg considerando x y y definidos arriba

# %%
bagging_logreg.fit(x_train, y_train)
y_pred_b = bagging_logreg.predict(x_test)
# Out:
# /Users/danielpoblano/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /Users/danielpoblano/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# Grafica la función de descisión dada por model y bagging_logreg ¿Qué observas?

# %%
plt.scatter(*x_test.T,c=y_pred_b,cmap="Set2")

# %%
import numpy as np
from matplotlib.colors import ListedColormap

def plot_classf_model(X, y, model, ax, title=None, step=0.01, epsilon=0.1, contour=False):
    """
    Contourplot a two-class underlying model, and test datapoints.
    
    Paramters
    ---------
    X: Matrix(mxn, R)
        Matrix of feature vectors with examples
    y: n-dimensional vector 
        Actual classes for each of the 'm' provided examples.
    """
    custom_cmap = ListedColormap(['#fafab0','#9898ff','#a0faa0'])
    points_cmap = ListedColormap(["Yellow", "Blue"])
    x0, x1 = X[:,0].min() - epsilon, X[:,0].max() + epsilon
    y0, y1 = X[:,1].min() - epsilon, X[:,1].max() + epsilon
    
    xx, yy = np.mgrid[x0:x1:step, y0:y1:step]
    
    preds = model.predict(np.c_[xx.ravel(), yy.ravel()])
    preds = preds.reshape(xx.shape)
    
    if contour:
        ax.contour(xx, yy, preds)
    ax.pcolormesh(xx, yy, preds, cmap=custom_cmap)
    
    ax.scatter(*X.T, c=y, s=50, edgecolor="k", cmap=points_cmap)
    if title is not None:
        ax.set_title(title)

# %%
fig, ax = plt.subplots()
plot_classf_model(X, y, bagging_logreg, ax=ax, contour=True, epsilon=0)

# %%
fig, ax = plt.subplots()
plot_classf_model(X, y, model, ax=ax, contour=True, epsilon=0)

# %%
y_pred_m = model.predict(x_test)
plt.scatter(*x_test.T,c=y_pred_m,cmap="Set2")

# %% [markdown]
# EL polinomio grado 30 está subre ajustando los datos, con bagging se empieza a hacer un 100 conjuntos con su estimador, para deahí abtener por voting y_pred. Esto hace que mejore la predicción aúnque se prodría con menos  n_estimators y un polinomio de menor grados.

# %%
from sklearn.metrics import f1_score
f1_score(y_pred_m, y_test)
# Out:
# 0.8000000000000002

# %%
f1_score(y_pred_b, y_test)
# Out:
# 0.9333333333333333
